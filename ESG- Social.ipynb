# %%
import pandas as pd
import seaborn as sns
import wbdata
import matplotlib.pyplot as plt
import numpy as np
import datetime
import plotly.express as px

# %%
# Female Salaries
fem_gdp = pd.read_csv('Resources/GDP_tertiary.csv')
main_fem = pd.read_csv('Resources/salaries_fem.csv')
#merge dataframes
merged_fem = pd.merge(fem_gdp, main_fem, on="Country")
merged_fem.head()
# Out:
#                 Country Code_x        2005_x        2006_x        2007_x  \
# 0           Afghanistan    AFG    242.031379    263.733735    359.693480
# 1                Angola    AGO   1902.422346   2599.566464   3121.995637
# 2               Albania    ALB   2673.787283   2972.743265   3595.037163
# 3            Arab World    ARB   3762.767087   4356.152316   4959.915010
# 4  United Arab Emirates    ARE  39365.335920  41907.405660  41809.516380
#
#          2008_x        2009_x        2010_x        2011_x        2012_x  ...  \
# 0    364.660465    438.076034    543.303042    591.162347    641.872034  ...
# 1   4080.941410   3122.780766   3587.883798   4615.468028   5100.095808  ...
# 2   4370.539925   4114.134899   4094.358816   4437.177794   4247.614342  ...
# 3   6143.170152   5182.363881   5945.678558   6889.091806   7503.174184  ...
# 4  44498.934230  32024.181600  33893.303510  39194.676620  40976.499710  ...
#
# ...

# %%
#rename
merged_fem = merged_fem.rename(columns={"2005_x": "2005 GDP", "2006_x": "2006 GDP", "2007_x": "2007 GDP", "2008_x": "2008 GDP", "2009_x": "2009 GDP", "2010_x": "2010 GDP","2011_x": "2011 GDP","2012_x": "2012 GDP","2013_x": "2013 GDP","2014_x": "2015 GDP","2015_x": "2016 GDP","2016_x": "2005 GDP","2017_x": "2017 GDP", "mean_x":'GDP Mean', "2005 Tertiary": "2005 Female","2006 Tertiary": "2006 Female","2007 Tertiary": "2007 Female","2008 Tertiary": "2008 Female","2009 Tertiary": "2009 Female","2010 Tertiary": "2010 Female","2011 Tertiary": "2011 Female","2012 Tertiary": "2012 Female","2013 Tertiary": "2013 Female","2014 Tertiary": "2014 Female","2015_y": "2015 Female","2016 Tertiary": "2016 Female","2017 Tertiary": "2017 Female","mean_y":"Female Mean"})
merged_fem.head()
# Out:
#                 Country Code_x      2005 GDP      2006 GDP      2007 GDP  \
# 0           Afghanistan    AFG    242.031379    263.733735    359.693480
# 1                Angola    AGO   1902.422346   2599.566464   3121.995637
# 2               Albania    ALB   2673.787283   2972.743265   3595.037163
# 3            Arab World    ARB   3762.767087   4356.152316   4959.915010
# 4  United Arab Emirates    ARE  39365.335920  41907.405660  41809.516380
#
#        2008 GDP      2009 GDP      2010 GDP      2011 GDP      2012 GDP  ...  \
# 0    364.660465    438.076034    543.303042    591.162347    641.872034  ...
# 1   4080.941410   3122.780766   3587.883798   4615.468028   5100.095808  ...
# 2   4370.539925   4114.134899   4094.358816   4437.177794   4247.614342  ...
# 3   6143.170152   5182.363881   5945.678558   6889.091806   7503.174184  ...
# 4  44498.934230  32024.181600  33893.303510  39194.676620  40976.499710  ...
#
# ...

# %%
# scatter plot
scatter_fem = px.scatter(merged_fem, y="GDP Mean", x="Female Mean",hover_data=['Country'])
scatter_fem.show()
# Out:
# <div>
#
#
#             <div id="1ea22e47-6a5f-4eea-a196-147c4e84e6ef" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1ea22e47-6a5f-4eea-a196-147c4e84e6ef")) {
#                     Plotly.newPlot(
#                         '1ea22e47-6a5f-4eea-a196-147c4e84e6ef',
# ...

# %%
#Male Salaries
mal_gdp = pd.read_csv('Resources/GDP_tertiary.csv')
main_mal = pd.read_csv('Resources/salaries_mal.csv')
#Merge Dataframes
merged_mal = pd.merge(mal_gdp, main_mal, on="Country")
merged_mal.head()
# Out:
#                 Country Code_x        2005_x        2006_x        2007_x  \
# 0           Afghanistan    AFG    242.031379    263.733735    359.693480
# 1                Angola    AGO   1902.422346   2599.566464   3121.995637
# 2               Albania    ALB   2673.787283   2972.743265   3595.037163
# 3            Arab World    ARB   3762.767087   4356.152316   4959.915010
# 4  United Arab Emirates    ARE  39365.335920  41907.405660  41809.516380
#
#          2008_x        2009_x        2010_x        2011_x        2012_x  ...  \
# 0    364.660465    438.076034    543.303042    591.162347    641.872034  ...
# 1   4080.941410   3122.780766   3587.883798   4615.468028   5100.095808  ...
# 2   4370.539925   4114.134899   4094.358816   4437.177794   4247.614342  ...
# 3   6143.170152   5182.363881   5945.678558   6889.091806   7503.174184  ...
# 4  44498.934230  32024.181600  33893.303510  39194.676620  40976.499710  ...
#
# ...

# %%
#Rename 
merged_mal = merged.rename(columns={"2005_x": "2005 GDP", "2006_x": "2006 GDP", "2007_x": "2007 GDP", "2008_x": "2008 GDP", "2009_x": "2009 GDP", "2010_x": "2010 GDP","2011_x": "2011 GDP","2012_x": "2012 GDP","2013_x": "2013 GDP","2014_x": "2015 GDP","2015_x": "2016 GDP","2016_x": "2005 GDP","2017_x": "2017 GDP", "mean_x":'GDP Mean', "2005_y": "2005 Male","2006_y": "2006 Male","2007_y": "2007 Male","2008_y": "2008 Male","2009_y": "2009 Male","2010_y": "2010 Male","2011_y": "2011 Male","2012_y": "2012 Male","2013_y": "2013 Male","2014_y": "2014 Male","2015_y": "2015 Male","2016_y": "2016 Male","2017_y": "2017 Male","mean_y":"Male Mean"})
merged_mal.head()
# Out:
#                 Country Code_x      2005 GDP      2006 GDP      2007 GDP  \
# 0           Afghanistan    AFG    242.031379    263.733735    359.693480
# 1                Angola    AGO   1902.422346   2599.566464   3121.995637
# 2               Albania    ALB   2673.787283   2972.743265   3595.037163
# 3            Arab World    ARB   3762.767087   4356.152316   4959.915010
# 4  United Arab Emirates    ARE  39365.335920  41907.405660  41809.516380
#
#        2008 GDP      2009 GDP      2010 GDP      2011 GDP      2012 GDP  ...  \
# 0    364.660465    438.076034    543.303042    591.162347    641.872034  ...
# 1   4080.941410   3122.780766   3587.883798   4615.468028   5100.095808  ...
# 2   4370.539925   4114.134899   4094.358816   4437.177794   4247.614342  ...
# 3   6143.170152   5182.363881   5945.678558   6889.091806   7503.174184  ...
# 4  44498.934230  32024.181600  33893.303510  39194.676620  40976.499710  ...
#
# ...

# %%
#scatter plot
scatter_mal = px.scatter(merged_mal, y="GDP Mean", x="Male Mean",hover_data=['Country'])
scatter_mal.show()
# Out:
# <div>
#
#
#             <div id="61434f1f-c026-4a5d-a881-62382024fed3" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("61434f1f-c026-4a5d-a881-62382024fed3")) {
#                     Plotly.newPlot(
#                         '61434f1f-c026-4a5d-a881-62382024fed3',
# ...

# %%
#LGBTQ acceptance
main_gdp = pd.read_csv('Resources/GDP_LGBTQ.csv')
main_LGBTQ = pd.read_csv('Resources/LGBTQ.csv')
#merge dataframes
merged_LGBTQ = pd.merge(main_gdp, main_LGBTQ, on="Country")
merged_LGBTQ.head()
# Out:
#        Country Code_x        2014_x        2015_x        2016_x        2017_x  \
# 0  Afghanistan    AFG    613.856333    578.466353    547.228110    556.302138
# 1       Angola    AGO   5408.410496   4166.979684   3506.072885   4095.812942
# 2      Albania    ALB   4578.667934   3952.830781   4124.108543   4532.889198
# 3    Argentina    ARG  12334.798250  13789.060420  12790.242470  14591.863380
# 4      Armenia    ARM   3986.231624   3607.296697   3591.829276   3914.501268
#
#         mean_x Code_y     2014_y     2015_y     2016_y     2017_y     mean_y
# 0  490.5808073    AFG   0.021395   0.021395   0.021395   0.082740   0.036731
# 1  3889.485585    AGO  17.408800  12.627000  12.627000  12.627000  13.822450
# 2  4008.228679    ALB   2.563200  10.562700  11.723600  10.641100   8.872650
# 3  10648.00263    ARG  67.870499  65.207802  65.181198  61.444698  64.926049
# 4  3331.573353    ARM   4.036600   4.876300   2.265300   1.784800   3.240750

# %%
#rename
merged_LGBTQ = merged.rename(columns={"2014_x": "2015 GDP","2015_x": "2016 GDP","2016_x": "2005 GDP","2017_x": "2017 GDP", "mean_x":'GDP Mean',"2014_y": "2014 LGBTQ","2015_y": "2015 LGBTQ","2016_y": "2016 LGBTQ","2017_y": "2017 LGBTQ","mean_y":"LGBTQ Mean"})
merged_LGBTQ.head()
# Out:
#                 Country Code_x        2005_x        2006_x        2007_x  \
# 0           Afghanistan    AFG    242.031379    263.733735    359.693480
# 1                Angola    AGO   1902.422346   2599.566464   3121.995637
# 2               Albania    ALB   2673.787283   2972.743265   3595.037163
# 3            Arab World    ARB   3762.767087   4356.152316   4959.915010
# 4  United Arab Emirates    ARE  39365.335920  41907.405660  41809.516380
#
#          2008_x        2009_x        2010_x        2011_x        2012_x  ...  \
# 0    364.660465    438.076034    543.303042    591.162347    641.872034  ...
# 1   4080.941410   3122.780766   3587.883798   4615.468028   5100.095808  ...
# 2   4370.539925   4114.134899   4094.358816   4437.177794   4247.614342  ...
# 3   6143.170152   5182.363881   5945.678558   6889.091806   7503.174184  ...
# 4  44498.934230  32024.181600  33893.303510  39194.676620  40976.499710  ...
#
# ...

# %%
#scatter plot
scatter_LGBTQ = px.scatter(merged_LGBTQ, y="GDP Mean", x="LGBTQ Mean",hover_data=['Country'])
scatter_LGBTQ
# Out:
# <div>
#
#
#             <div id="28db135a-8178-4eda-9552-3d2fd75e88f2" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("28db135a-8178-4eda-9552-3d2fd75e88f2")) {
#                     Plotly.newPlot(
#                         '28db135a-8178-4eda-9552-3d2fd75e88f2',
# ...

# %%
#health expenditure
health_gdp = pd.read_csv('Resources/GDP.csv')
main_health = pd.read_csv('Resources/Health.csv')
#merge dataframes
merged_health = pd.merge(health_gdp, main_health, on="Country")
merged_health.head()
# Out:
#        Country Code_x        2005_x        2006_x        2007_x        2008_x  \
# 0  Afghanistan    AFG    242.031379    263.733735    359.693480    364.660465
# 1       Angola    AGO   1902.422346   2599.566464   3121.995637   4080.941410
# 2      Albania    ALB   2673.787283   2972.743265   3595.037163   4370.539925
# 3      Andorra    AND  41282.020120  43747.691850  48582.220880  47785.089270
# 4   Arab World    ARB   3762.767087   4356.152316   4959.915010   6143.170152
#
#          2009_x        2010_x        2011_x        2012_x  ...     2008_y  \
# 0    438.076034    543.303042    591.162347    641.872034  ...  10.256496
# 1   3122.780766   3587.883798   4615.468028   5100.095808  ...   3.495036
# 2   4114.134899   4094.358816   4437.177794   4247.614342  ...   5.566589
# 3  43338.866760  39736.354060  41100.729940  38392.943900  ...   8.792542
# 4   5182.363881   5945.678558   6889.091806   7503.174184  ...   3.404322
#
# ...

# %%
#rename
merged_health = merged_health.rename(columns={"2005_x": "2005 GDP", "2006_x": "2006 GDP", "2007_x": "2007 GDP", "2008_x": "2008 GDP", "2009_x": "2009 GDP", "2010_x": "2010 GDP","2011_x": "2011 GDP","2012_x": "2012 GDP","2013_x": "2013 GDP","2014_x": "2015 GDP","2015_x": "2016 GDP","2016_x": "2005 GDP","2017_x": "2017 GDP", "mean_x":'GDP Mean', "2005_y": "2005 Health","2006_y": "2006 Health","2007_y": "2007 Health","2008_y": "2008 Health","2009_y": "2009 Health","2010_y": "2010 Health","2011_y": "2011 Health","2012_y": "2012 Health","2013_y": "2013 Health","2014_y": "2014 Health","2015_y": "2015 Health","2016_y": "2016 Health","mean_y":"Health Mean"})
merged_health.head()
# Out:
#        Country Code_x      2005 GDP      2006 GDP      2007 GDP      2008 GDP  \
# 0  Afghanistan    AFG    242.031379    263.733735    359.693480    364.660465
# 1       Angola    AGO   1902.422346   2599.566464   3121.995637   4080.941410
# 2      Albania    ALB   2673.787283   2972.743265   3595.037163   4370.539925
# 3      Andorra    AND  41282.020120  43747.691850  48582.220880  47785.089270
# 4   Arab World    ARB   3762.767087   4356.152316   4959.915010   6143.170152
#
#        2009 GDP      2010 GDP      2011 GDP      2012 GDP  ...  2008 Health  \
# 0    438.076034    543.303042    591.162347    641.872034  ...    10.256496
# 1   3122.780766   3587.883798   4615.468028   5100.095808  ...     3.495036
# 2   4114.134899   4094.358816   4437.177794   4247.614342  ...     5.566589
# 3  43338.866760  39736.354060  41100.729940  38392.943900  ...     8.792542
# 4   5182.363881   5945.678558   6889.091806   7503.174184  ...     3.404322
#
# ...

# %%
#scatter plot
scatter_health = px.scatter(merged_health, y="GDP Mean", x="Health Mean",hover_data=['Country'])
scatter_health.show()
# Out:
# <div>
#
#
#             <div id="3a545b5b-a25a-4e80-944b-bc23a12b15c5" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3a545b5b-a25a-4e80-944b-bc23a12b15c5")) {
#                     Plotly.newPlot(
#                         '3a545b5b-a25a-4e80-944b-bc23a12b15c5',
# ...

# %%
#tertiary education
tertiary_gdp = pd.read_csv('Resources/GDP_tertiary.csv')
main_tertiary = pd.read_csv('Resources/Tertiary.csv')
#merge dataframes
merged_tertiary = pd.merge(tertiary_gdp, main_tertiary, on="Country")
merged_tertiary.head()
# Out:
#        Country Code_x        2005_x        2006_x        2007_x        2008_x  \
# 0        Aruba    ABW  23300.039560  24045.272480  25835.132670  27084.703690
# 1  Afghanistan    AFG    242.031379    263.733735    359.693480    364.660465
# 2       Angola    AGO   1902.422346   2599.566464   3121.995637   4080.941410
# 3      Albania    ALB   2673.787283   2972.743265   3595.037163   4370.539925
# 4   Arab World    ARB   3762.767087   4356.152316   4959.915010   6143.170152
#
#          2009_x        2010_x        2011_x        2012_x  ...     2009_y  \
# 0  24630.453710  23512.602600  24985.993280  24713.698050  ...  35.362320
# 1    438.076034    543.303042    591.162347    641.872034  ...   3.817950
# 2   3122.780766   3587.883798   4615.468028   5100.095808  ...        NaN
# 3   4114.134899   4094.358816   4437.177794   4247.614342  ...  33.630871
# 4   5182.363881   5945.678558   6889.091806   7503.174184  ...  24.063959
#
# ...

# %%
#rename
merged_tertiary= merged.rename(columns={"2005_x": "2005 GDP", "2006_x": "2006 GDP", "2007_x": "2007 GDP", "2008_x": "2008 GDP", "2009_x": "2009 GDP", "2010_x": "2010 GDP","2011_x": "2011 GDP","2012_x": "2012 GDP","2013_x": "2013 GDP","2014_x": "2015 GDP","2015_x": "2016 GDP","2016_x": "2005 GDP","2017_x": "2017 GDP", "mean_x":'GDP Mean', "2005_y": "2005 Tertiary","2006_y": "2006 Tertiary","2007_y": "2007 Tertiary","2008_y": "2008 Tertiary","2009_y": "2009 Tertiary","2010_y": "2010 Tertiary","2011_y": "2011 Tertiary","2012_y": "2012 Tertiary","2013_y": "2013 Tertiary","2014_y": "2014 Tertiary","2015 LGBTQ": "2015 Tertiary","2016_y": "2016 Tertiary","2017_y": "2017 Tertiary","mean_y":"Tertiary Mean"})
merged_tertiary.head()
# Out:
#                 Country Code_x      2005 GDP      2006 GDP      2007 GDP  \
# 0           Afghanistan    AFG    242.031379    263.733735    359.693480
# 1                Angola    AGO   1902.422346   2599.566464   3121.995637
# 2               Albania    ALB   2673.787283   2972.743265   3595.037163
# 3            Arab World    ARB   3762.767087   4356.152316   4959.915010
# 4  United Arab Emirates    ARE  39365.335920  41907.405660  41809.516380
#
#        2008 GDP      2009 GDP      2010 GDP      2011 GDP      2012 GDP  ...  \
# 0    364.660465    438.076034    543.303042    591.162347    641.872034  ...
# 1   4080.941410   3122.780766   3587.883798   4615.468028   5100.095808  ...
# 2   4370.539925   4114.134899   4094.358816   4437.177794   4247.614342  ...
# 3   6143.170152   5182.363881   5945.678558   6889.091806   7503.174184  ...
# 4  44498.934230  32024.181600  33893.303510  39194.676620  40976.499710  ...
#
# ...

# %%
#scatter plot
scatter_tertiary = px.scatter(merged_tertiary, y="GDP Mean", x="Tertiary Mean",hover_data=['Country'])
scatter_tertiary.show()
# Out:
# <div>
#
#
#             <div id="47d5e21e-56ae-46ae-bfb0-4a86d38099e5" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("47d5e21e-56ae-46ae-bfb0-4a86d38099e5")) {
#                     Plotly.newPlot(
#                         '47d5e21e-56ae-46ae-bfb0-4a86d38099e5',
# ...

# %%
# Out:
# <div>
#
#
#             <div id="a7081e48-3891-4b38-9854-9b896eaf06d7" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a7081e48-3891-4b38-9854-9b896eaf06d7")) {
#                     Plotly.newPlot(
#                         'a7081e48-3891-4b38-9854-9b896eaf06d7',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-817c450cdf4e> in <module>
#       2 main_ruleoflaw.head(2)
#       3 fig = px.choropleth(main_ruleoflaw , locations="Code",
# ----> 4                     color=year_interested,
#       5                     hover_name='Country',
#       6                     color_continuous_scale=px.colors.sequential.Plasma)
#
# NameError: name 'year_interested' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-eb3eefd4be47> in <module>()
#       1 import plotly.express as px
#       2
# ----> 3 fig = px.choropleth(pol_stability_noviolence, locations="Code",
#       4                     color="2017", # lifeExp is a column of gapminder
#       5                     #hover_name='Country', # column to add to hover information
#
# NameError: name 'pol_stability_noviolence' is not defined
